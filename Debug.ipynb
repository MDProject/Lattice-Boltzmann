# %%
import yt
from matplotlib import rc_context
from matplotlib.animation import FuncAnimation
print(yt.__version__)
plot_file_dir = "./equilibrium_rho" #"./lbm_data_shshan_alpha0_3_xi_0/plt00100"
ds = yt.load(plot_file_dir)
print(ds.field_list)
#slc = yt.SlicePlot(ds, "z", ('boxlib','afx')) #center=[0.5, 0.5, 0.5]
#slc.set_log(('boxlib','afx'), False)
#slc.set_zlim(("boxlib", "p_bulk"), 0., 1.2)
#slc.center
#slc.show()
#slc = yt.SlicePlot(ds, "z", ('boxlib','afy')) #center=[0.5, 0.5, 0.5]
#slc.set_log(('boxlib','afx'), False)
#slc.set_zlim(("boxlib", "p_bulk"), 0., 1.2)
#slc.center
#slc.show()
#slc = yt.SlicePlot(ds, "z", ('boxlib','afz')) #center=[0.5, 0.5, 0.5]
#slc.set_log(('boxlib','afx'), False)
#slc.set_zlim(("boxlib", "p_bulk"), 0., 1.2)
#slc.center
#slc.show()
slc = yt.SlicePlot(ds, "z", ('boxlib','rho_eq')) #center=[0.5, 0.5, 0.5]
slc.set_log(('boxlib','rho_eq'), False)
slc.set_zlim(("boxlib", "rho_eq"), 0., 1.2)
#slc.center
slc.show()
# Out:
# yt : [INFO     ] 2024-12-20 03:33:19,316 Parameters: current_time              = 0.0
# yt : [INFO     ] 2024-12-20 03:33:19,317 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2024-12-20 03:33:19,317 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-20 03:33:19,320 Parameters: domain_right_edge         = [1. 1. 1.]
# 4.4.0
# yt : [INFO     ] 2024-12-20 03:33:19,527 xlim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-20 03:33:19,528 ylim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-20 03:33:19,533 xlim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-20 03:33:19,535 ylim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-20 03:33:19,540 Making a fixed resolution buffer of (('boxlib', 'rho_eq')) 800 by 800
# [('boxlib', 'rho_eq')]
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os
from PIL import Image
def read_images_from_directory(directory):
    images = []
    for filename in os.listdir(directory):
        if filename.endswith(".jpg") or filename.endswith(".png"):  # Check for image file extensions
            filepath = os.path.join(directory, filename)
            images.append(filepath)
    return images

fig, ax = plt.subplots()

#img = plt.imread("./tau_2_alpha_3_xi_0/48.png")

images = []
images_path = read_images_from_directory("./IMG_shshan_alpha_0_xi_0/")
for filePath in images_path:
    img = plt.imread(str(filePath))
    im = ax.imshow(img, animated=True)
    images.append([im])

ani = animation.ArtistAnimation(fig, images, interval=500, blit=True, repeat_delay=1000)
writergif = animation.PillowWriter(fps=3)
ani.save('filename.gif',writer=writergif)
plt.show()

# %%
#   IMG*** generation for each step

import yt
file_path = "./lbm_data_shshan_alpha0_4_xi_mass1e-5/"   # 1e-5mass is the kBT value
ts = yt.load(file_path + "plt*")
ac = 0
for fr in ts:
    slc = yt.SlicePlot(fr, "z", ('boxlib','rho')) #center=[0.5, 0.5, 0.5]
    slc.set_log(('boxlib','rho'), False)
    slc.set_zlim('rho', -0.5, 1.2)
    #slc.show()
    filename = "./IMG_shshan_alpha0_4_xi_mass1e-5/" + str(ac) + ".png" 
    slc.save(filename)
    ac = ac + 1
# Out:
# yt : [INFO     ] 2024-12-20 03:34:02,628 Parameters: current_time              = 0.0
# yt : [INFO     ] 2024-12-20 03:34:02,629 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2024-12-20 03:34:02,630 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-20 03:34:02,631 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2024-12-20 03:34:02,808 xlim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-20 03:34:02,809 ylim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-20 03:34:02,813 xlim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-20 03:34:02,814 ylim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-20 03:34:02,818 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# yt : [INFO     ] 2024-12-20 03:34:03,437 Saving plot ./IMG_shshan_alpha0_4_xi_mass1e-5/0.png
# yt : [INFO     ] 2024-12-20 03:34:03,727 Parameters: current_time              = 10.0
# ...
