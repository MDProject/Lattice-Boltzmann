# %%
import yt
from matplotlib import rc_context
from matplotlib.animation import FuncAnimation
print(yt.__version__)
plot_file_dir = "./equilibrium_rho" #"./lbm_data_shshan_alpha0_3_xi_0/plt00100"
ds = yt.load(plot_file_dir)
print(ds.field_list)
#slc = yt.SlicePlot(ds, "z", ('boxlib','afx')) #center=[0.5, 0.5, 0.5]
#slc.set_log(('boxlib','afx'), False)
#slc.set_zlim(("boxlib", "p_bulk"), 0., 1.2)
#slc.center
#slc.show()
#slc = yt.SlicePlot(ds, "z", ('boxlib','afy')) #center=[0.5, 0.5, 0.5]
#slc.set_log(('boxlib','afx'), False)
#slc.set_zlim(("boxlib", "p_bulk"), 0., 1.2)
#slc.center
#slc.show()
#slc = yt.SlicePlot(ds, "z", ('boxlib','afz')) #center=[0.5, 0.5, 0.5]
#slc.set_log(('boxlib','afx'), False)
#slc.set_zlim(("boxlib", "p_bulk"), 0., 1.2)
#slc.center
#slc.show()
slc = yt.SlicePlot(ds, "z", ('boxlib','rho_eq')) #center=[0.5, 0.5, 0.5]
slc.set_log(('boxlib','rho_eq'), False)
slc.set_zlim(("boxlib", "rho_eq"), 0., 1.2)
#slc.center
slc.show()
# Out:
# yt : [INFO     ] 2024-12-09 14:48:52,511 Parameters: current_time              = 0.0
# yt : [INFO     ] 2024-12-09 14:48:52,512 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2024-12-09 14:48:52,513 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-09 14:48:52,514 Parameters: domain_right_edge         = [1. 1. 1.]
# 4.4.0
# [('boxlib', 'rho_eq')]
# ---------------------------------------------------------------------------
# YTFieldNotFound                           Traceback (most recent call last)
# Cell In[4], line 23
#       7 print(ds.field_list)
#       8 #slc = yt.SlicePlot(ds, "z", ('boxlib','afx')) #center=[0.5, 0.5, 0.5]
#       9 #slc.set_log(('boxlib','afx'), False)
#      10 #slc.set_zlim(("boxlib", "p_bulk"), 0., 1.2)
#    (...)
#      21 #slc.center
#      22 #slc.show()
# ---> 23 slc = yt.SlicePlot(ds, "z", ('boxlib','rho')) #center=[0.5, 0.5, 0.5]
#      24 slc.set_log(('boxlib','rho'), False)
#      25 slc.set_zlim(("boxlib", "rho"), 0., 1.2)
#
# File ~/opt/anaconda3/envs/base_new/lib/python3.13/site-packages/yt/visualization/plot_window.py:1856, in AxisAlignedSlicePlot.__init__(self, ds, normal, fields, center, width, axes_unit, origin, fontsize, field_parameters, window_size, aspect, data_source, buff_size, north_vector)
#    1848 else:
#    1849     slc = ds.slice(
#    1850         axis,
#    1851         center[axis],
#    (...)
#    1854         data_source=data_source,
#    1855     )
# -> 1856     slc.get_data(fields)
#    1857 validate_mesh_fields(slc, fields)
#    1858 PWViewerMPL.__init__(
#    1859     self,
#    1860     slc,
#    (...)
#    1868     geometry=ds.geometry,
#    1869 )
#
# File ~/opt/anaconda3/envs/base_new/lib/python3.13/site-packages/yt/data_objects/selection_objects/data_selection_objects.py:144, in YTSelectionContainer.get_data(self, fields)
#     142 nfields = []
#     143 apply_fields = defaultdict(list)
# --> 144 for field in self._determine_fields(fields):
#     145     # We need to create the field on the raw particle types
#     146     # for particles types (when the field is not directly
#     147     # defined for the derived particle type only)
#     148     finfo = self.ds.field_info[field]
#     150     if (
#     151         field[0] in self.ds.filtered_particle_types
#     152         and finfo._inherited_particle_filter
#     153     ):
#
# File ~/opt/anaconda3/envs/base_new/lib/python3.13/site-packages/yt/data_objects/data_containers.py:1471, in YTDataContainer._determine_fields(self, fields)
#    1468     explicit_fields.append(field)
#    1469     continue
# -> 1471 finfo = self.ds._get_field_info(field)
#    1472 ftype, fname = finfo.name
#    1473 # really ugly check to ensure that this field really does exist somewhere,
#    1474 # in some naming convention, before returning it as a possible field type
#
# File ~/opt/anaconda3/envs/base_new/lib/python3.13/site-packages/yt/data_objects/static_output.py:953, in Dataset._get_field_info(self, field)
#     948 def _get_field_info(
#     949     self,
#     950     field: FieldKey | ImplicitFieldKey | DerivedField,
#     951     /,
#     952 ) -> DerivedField:
# --> 953     field_info, candidates = self._get_field_info_helper(field)
#     955     if field_info.name[1] in ("px", "py", "pz", "pdx", "pdy", "pdz"):
#     956         # escape early as a bandaid solution to
#     957         # https://github.com/yt-project/yt/issues/3381
#     958         return field_info
#
# File ~/opt/anaconda3/envs/base_new/lib/python3.13/site-packages/yt/data_objects/static_output.py:1046, in Dataset._get_field_info_helper(self, field)
#    1043 elif (ftype, fname) in self.field_info:
#    1044     return self.field_info[ftype, fname], []
# -> 1046 raise YTFieldNotFound(field, ds=self)
#
# YTFieldNotFound: Could not find field ('boxlib', 'rho') in equilibrium_rho.

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import os
from PIL import Image
def read_images_from_directory(directory):
    images = []
    for filename in os.listdir(directory):
        if filename.endswith(".jpg") or filename.endswith(".png"):  # Check for image file extensions
            filepath = os.path.join(directory, filename)
            images.append(filepath)
    return images

fig, ax = plt.subplots()

#img = plt.imread("./tau_2_alpha_3_xi_0/48.png")

images = []
images_path = read_images_from_directory("./IMG_shshan_alpha_0_xi_0/")
for filePath in images_path:
    img = plt.imread(str(filePath))
    im = ax.imshow(img, animated=True)
    images.append([im])

ani = animation.ArtistAnimation(fig, images, interval=500, blit=True, repeat_delay=1000)
writergif = animation.PillowWriter(fps=3)
ani.save('filename.gif',writer=writergif)
plt.show()

# %%
#   IMG*** generation for each step

import yt
file_path = "./lbm_data_shshan_alpha0_4_xi_0/"   # 1e-5mass is the kBT value
ts = yt.load(file_path + "plt*")
ac = 0
for fr in ts:
    slc = yt.SlicePlot(fr, "z", ('boxlib','rho')) #center=[0.5, 0.5, 0.5]
    slc.set_log(('boxlib','rho'), False)
    slc.set_zlim('rho', -0.5, 1.2)
    #slc.show()
    filename = "./IMG_shshan_alpha0_4_xi_0/" + str(ac) + ".png" 
    slc.save(filename)
    ac = ac + 1
# Out:
# yt : [INFO     ] 2024-12-09 14:40:43,126 Parameters: current_time              = 0.0
# yt : [INFO     ] 2024-12-09 14:40:43,127 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2024-12-09 14:40:43,129 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-09 14:40:43,133 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2024-12-09 14:40:43,441 xlim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-09 14:40:43,441 ylim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-09 14:40:43,444 xlim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-09 14:40:43,445 ylim = 0.000000 1.000000
# yt : [INFO     ] 2024-12-09 14:40:43,450 Making a fixed resolution buffer of (('boxlib', 'rho')) 800 by 800
# yt : [INFO     ] 2024-12-09 14:40:44,461 Saving plot ./IMG_shshan_alpha0_4_xi_0/0.png
# yt : [INFO     ] 2024-12-09 14:40:44,832 Parameters: current_time              = 10.0
# yt : [INFO     ] 2024-12-09 14:40:44,833 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 